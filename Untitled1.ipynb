# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('medical_examination.csv')
df['overweight'] = (df['weight'] / ((df['height']/100 ) **2)).apply(lambda x: 1 if x>25 else 0)
df['cholesterol'] = df['cholesterol'].apply(lambda x: 1 if x >1 else 0  )
df['gluc'] = df['gluc'].apply(lambda x: 1 if x >1 else 0  )
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69996  99995  22601    1     158   126.0    140     90            1     1
# 69997  99996  19066    2     183   105.0    180     90            1     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# ...

# %%
cat = pd.melt(df, id_vars =['cardio'], value_vars = ['cholesterol', 'gluc', 'smoke' , 'alco', 'active', 'overweight'])
cat = cat.groupby(['cardio', 'variable', 'value'],as_index=False)['value'].size().reset_index().rename(columns={0:'total'})
cat
# Out:
#     cardio     variable  value  total
# 0        0       active      0   6378
# 1        0       active      1  28643
# 2        0         alco      0  33080
# 3        0         alco      1   1941
# 4        0  cholesterol      0  29330
# 5        0  cholesterol      1   5691
# 6        0         gluc      0  30894
# 7        0         gluc      1   4127
# 8        0   overweight      0  15915
# 9        0   overweight      1  19106
# 10       0        smoke      0  31781
# 11       0        smoke      1   3240
# 12       1       active      0   7361
# 13       1       active      1  27618
# 14       1         alco      0  33156
# 15       1         alco      1   1823
# 16       1  cholesterol      0  23055
# 17       1  cholesterol      1  11924
# 18       1         gluc      0  28585
# 19       1         gluc      1   6394
# 20       1   overweight      0  10539
# 21       1   overweight      1  24440
# 22       1        smoke      0  32050
# 23       1        smoke      1   2929

# %%
sns.catplot( x = 'variable', y='total', hue='value', col='cardio',
                data=cat,
                kind="bar")

# %%
cat.size()
# Out:
# cardio  variable     value
# 0       active       0         6378
#                      1        28643
#         alco         0        33080
#                      1         1941
#         cholesterol  0        29330
#                      1         5691
#         gluc         0        30894
#                      1         4127
#         overweight   0        15915
#                      1        19106
#         smoke        0        31781
#                      1         3240
# 1       active       0         7361
#                      1        27618
#         alco         0        33156
#                      1         1823
#         cholesterol  0        23055
#                      1        11924
#         gluc         0        28585
#                      1         6394
#         overweight   0        10539
#                      1        24440
#         smoke        0        32050
#                      1         2929
# dtype: int64

# %%
heat = df[(df['ap_lo'] <= df['ap_hi']) & (df['height'] >= df['height'].quantile(0.025)) & (df['height'] <= df['height'].quantile(0.975)) & (df['weight'] >= df['weight'].quantile(0.025)) & (df['weight'] <= df['weight'].quantile(0.975))]
corr = heat.corr()
mask = np.triu(np.ones_like(corr))
fig, ax = plt.subplots(figsize=(7, 5))

    # Draw the heatmap with 'sns.heatmap()'
ax = sns.heatmap(corr.round(1),fmt= '.1f', mask=mask, vmax=.3,square=True, annot=True)
ax

# %%
df_heat = df.loc[(df['ap_lo'] <= df['ap_hi']) & (df['height'] >= df['height'].quantile(0.025)) & (df['height'] <= df['height'].quantile(0.975)) & (df['weight'] >= df['weight'].quantile(0.025)) & (df['weight'] <= df['weight'].quantile(0.975))]
df_heat
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69993  99991  19699    1     172    70.0    130     90            0     0
# 69994  99992  21074    1     165    80.0    150     80            0     0
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# ...
